# %%
import pandas as pd
import matplotlib

# %%
tt=pd.read_csv('http://data.cityofnewyork.us/api/views/h9gi-nx95/rows.csv')
tt.head()

# %%
train = pd.read_csv('~/Downloads/nypd-motor-vehicle-collisions.csv')
train.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                   DATE  TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  2018-11-16T00:00:00  0:10  MANHATTAN    10010  40.742275 -73.988914
# 1  2018-11-16T00:00:00  0:40        NaN      NaN  40.762720 -73.728170
# 2  2018-11-16T00:00:00  0:45   BROOKLYN    11211  40.710197 -73.958430
# 3  2018-11-16T00:00:00  1:00      BRONX    10454  40.803555 -73.911840
# 4  2018-11-16T00:00:00  1:00   BROOKLYN    11221  40.694923 -73.915565
#
#                                             LOCATION  \
# 0  {'longitude': '-73.988914', 'latitude': '40.74...
# 1  {'longitude': '-73.72817', 'latitude': '40.762...
# 2  {'longitude': '-73.95843', 'latitude': '40.710...
# 3  {'longitude': '-73.91184', 'latitude': '40.803...
# 4  {'longitude': '-73.915565', 'latitude': '40.69...
#
#                      ON STREET NAME CROSS STREET NAME OFF STREET NAME  ...  \
# 0  5 AVENUE                                  BROADWAY             NaN  ...
# 1  LONG ISLAND EXPRESSWAY                         NaN             NaN  ...
# 2  BORINQUEN PLACE                   HAVEMEYER STREET             NaN  ...
# 3  EAST 137 STREET                      WILLOW AVENUE             NaN  ...
# 4  WILSON AVENUE                      PALMETTO STREET             NaN  ...
#
#     CONTRIBUTING FACTOR VEHICLE 2  CONTRIBUTING FACTOR VEHICLE 3  \
# 0                     Unspecified                            NaN
# 1               Pavement Slippery                            NaN
# 2  Driver Inattention/Distraction                            NaN
# 3                     Unspecified                            NaN
# 4                     Unspecified                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  UNIQUE KEY  \
# 0                            NaN                            NaN     4021880
# 1                            NaN                            NaN     4021727
# 2                            NaN                            NaN     4021791
# 3                            NaN                            NaN     4021878
# 4                            NaN                            NaN     4021848
#
#                    VEHICLE TYPE CODE 1                  VEHICLE TYPE CODE 2  \
# 0  Station Wagon/Sport Utility Vehicle  Station Wagon/Sport Utility Vehicle
# 1                                Sedan                        Pick-up Truck
# 2                                 Taxi                                 Taxi
# 3                    Garbage or Refuse  Station Wagon/Sport Utility Vehicle
# 4  Station Wagon/Sport Utility Vehicle  Station Wagon/Sport Utility Vehicle
#
#    VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
#
# [5 rows x 29 columns]

# %%
train.columns.to_list()
# Out:
# [':@computed_region_92fq_4b7q',
#  ':@computed_region_efsh_h5xi',
#  ':@computed_region_f5dn_yrer',
#  ':@computed_region_sbqj_enih',
#  ':@computed_region_yeji_bk3q',
#  'borough',
#  'contributing_factor_vehicle_1',
#  'contributing_factor_vehicle_2',
#  'contributing_factor_vehicle_3',
#  'contributing_factor_vehicle_4',
#  'contributing_factor_vehicle_5',
#  'cross_street_name',
#  'date',
#  'latitude',
#  'location',
#  'location_address',
#  'location_city',
#  'location_state',
#  'location_zip',
#  'longitude',
#  'number_of_cyclist_injured',
#  'number_of_cyclist_killed',
#  'number_of_motorist_injured',
#  'number_of_motorist_killed',
#  'number_of_pedestrians_injured',
#  'number_of_pedestrians_killed',
#  'number_of_persons_injured',
#  'number_of_persons_killed',
#  'off_street_name',
#  'on_street_name',
#  'time',
#  'unique_key',
#  'vehicle_type_code1',
#  'vehicle_type_code2',
#  'vehicle_type_code_3',
#  'vehicle_type_code_4',
#  'vehicle_type_code_5',
#  'zip_code']

# %%
# train.DATE.value_counts().head().plot.bar()
train.DATE.value_counts().head().plot.line()

# %%
train.plot(x='DATE', y='NUMBER OF PERSONS INJURED', rot=90)

# %%
type(train.DATE)
train.DATE = pd.to_datetime(train.DATE, infer_datetime_format=True)
type(train.DATE)
# Out:
# pandas.core.series.Series

# %%
from pandas import Grouper
train.groupby(Grouper(key='DATE', freq='M')).sum().head()
# Out:
#                  LATITUDE     LONGITUDE  NUMBER OF PERSONS INJURED  \
# DATE
# 2012-07-31  589856.500723 -1.070855e+06                     4855.0
# 2012-08-31  591480.272775 -1.073838e+06                     4750.0
# 2012-09-30  574179.219528 -1.042394e+06                     4689.0
# 2012-10-31  581920.216678 -1.056455e+06                     4572.0
# 2012-11-30  548462.181483 -9.958321e+05                     3995.0
#
#             NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# DATE
# 2012-07-31                      22.0                            855
# 2012-08-31                      27.0                            850
# 2012-09-30                      26.0                            893
# 2012-10-31                      21.0                            977
# 2012-11-30                      14.0                           1037
#
#             NUMBER OF PEDESTRIANS KILLED  NUMBER OF CYCLIST INJURED  \
# DATE
# 2012-07-31                             6                        450
# 2012-08-31                            15                        507
# 2012-09-30                            13                        434
# 2012-10-31                            13                        329
# 2012-11-30                             8                        277
#
#             NUMBER OF CYCLIST KILLED  NUMBER OF MOTORIST INJURED  \
# DATE
# 2012-07-31                         3                        3550
# 2012-08-31                         1                        3393
# 2012-09-30                         1                        3362
# 2012-10-31                         1                        3260
# 2012-11-30                         0                        2681
#
#             NUMBER OF MOTORIST KILLED  UNIQUE KEY
# DATE
# 2012-07-31                         13  8006752543
# 2012-08-31                         11  8436607385
# 2012-09-30                         12  7790616930
# 2012-10-31                          7  7968470292
# 2012-11-30                          6  7575424083

# %%
train.groupby(Grouper(key='DATE', freq='M')).sum().plot.line(y=['NUMBER OF PERSONS INJURED', 
                                                                'NUMBER OF PERSONS KILLED'],
                                                            secondary_y=1)

# %%
train['UNIQUE KEY'].describe()
train['UNIQUE KEY'].isnull().any()
# Out:
# False

# %%
train['CONTRIBUTING FACTOR VEHICLE 1'].value_counts().head().plot.line(rot=90)

# %%
train['VEHICLE TYPE CODE 1'].value_counts().head().plot.line(rot=90)

# %%
train.TIME = pd.to_datetime(train.TIME, infer_datetime_format=True)

train.groupby(Grouper(key='TIME', freq='H')).sum().plot.line(y=['NUMBER OF PERSONS INJURED', 
                                                                'NUMBER OF PERSONS KILLED'],
                                                            secondary_y=1)

# %%
train.groupby(Grouper(key='TIME', freq='H')).sum().plot.line(y='NUMBER OF PERSONS KILLED',
                                                            )

# %%
train.groupby('BOROUGH').sum()
# Out:
#                    LATITUDE     LONGITUDE  NUMBER OF PERSONS INJURED  \
# BOROUGH
# BRONX          5.109961e+06 -9.242094e+06                    37644.0
# BROOKLYN       1.165269e+07 -2.119582e+07                    87426.0
# MANHATTAN      9.294865e+06 -1.686753e+07                    41242.0
# QUEENS         9.917396e+06 -1.798199e+07                    66739.0
# STATEN ISLAND  1.711804e+06 -3.126288e+06                    10633.0
#
#                NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# BOROUGH
# BRONX                             148.0                           9207
# BROOKLYN                          342.0                          19821
# MANHATTAN                         194.0                          14432
# QUEENS                            317.0                          13477
# STATEN ISLAND                      59.0                           1613
#
#                NUMBER OF PEDESTRIANS KILLED  NUMBER OF CYCLIST INJURED  \
# BOROUGH
# BRONX                                    85                       2177
# BROOKLYN                                197                       9306
# MANHATTAN                               145                       7010
# QUEENS                                  179                       4584
# STATEN ISLAND                            24                        264
#
#                NUMBER OF CYCLIST KILLED  NUMBER OF MOTORIST INJURED  \
# BOROUGH
# BRONX                                10                       26386
# BROOKLYN                             30                       58656
# MANHATTAN                            22                       20049
# QUEENS                               22                       49048
# STATEN ISLAND                         2                        8813
#
#                NUMBER OF MOTORIST KILLED    UNIQUE KEY
# BOROUGH
# BRONX                                 54  322776367938
# BROOKLYN                             113  717114307917
# MANHATTAN                             27  531776970490
# QUEENS                               116  621748512313
# STATEN ISLAND                         34   98535942160

# %%
train.groupby('BOROUGH').sum().plot.line(y='NUMBER OF PERSONS INJURED')

# %%
train.groupby('BOROUGH').sum().plot.line(y='NUMBER OF PERSONS KILLED')
